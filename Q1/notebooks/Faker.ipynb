# %%
# !pip install faker

from faker import Faker
import csv
output=open('/home/data_in/data.csv','w')
fake=Faker()
header=['name','age','street','city','state','zip','lng','lat']
mywriter=csv.writer(output)
mywriter.writerow(header)
for r in range(100):
    row =[fake.name(),fake.random_int(min=18,max=80, step=1), 
                       fake.street_address(), fake.city(),fake.state(),
                       fake.zipcode(),fake.longitude(),fake.latitude()]
    print(row)
    mywriter.writerow(row)

output.close()
# Out:
# ...
# ['Timothy Gordon', 38, '0907 Ross Mount', 'Kathyfurt', 'Hawaii', '75336', Decimal('88.657193'), Decimal('33.5604945')]
# ['Jessica Cohen', 63, '07639 Madison Shores Suite 562', 'Wilsonhaven', 'California', '81129', Decimal('-34.812239'), Decimal('-3.854265')]
# ['Lisa Williams', 29, '69618 Johnson Plaza', 'Thomasstad', 'Oklahoma', '11409', Decimal('130.352913'), Decimal('-25.1793935')]
# ['Roy Velazquez', 53, '4692 Miller Burg Apt. 017', 'Colemanview', 'New Jersey', '92219', Decimal('21.312585'), Decimal('-82.4039675')]
# ['Paul Cameron', 43, '09651 Alexandria Crossroad Apt. 335', 'New Michaelville', 'Vermont', '02241', Decimal('167.850916'), Decimal('89.0385565')]
# ['Manuel Lloyd', 27, '419 Sloan Plaza', 'Port Traciland', 'Hawaii', '28834', Decimal('-110.496358'), Decimal('54.7462205')]
# ['Luis Robinson', 57, '640 Jamie Stream Apt. 880', 'Calebmouth', 'New York', '49910', Decimal('73.856902'), Decimal('-6.832327')]
# ...
